# %% [markdown]
# # GeoSpatial Public Policy Analysis - PyCon 2020
# #### A repository containing the materials for the tutorial Geospatial Public Policy Analysis with GeoPandas for PyCon 2020. To be delivered virtually.
#
# <details>
#     <summary><strong>Goal</strong></summary>
#     The goal of this notebook is to process NCES IPEDS tabular data into an analytical file (subset) that will be used in another notebook to visualize education deserts.
#     <ul>
#         <li> Measurable goals for this notebook:</li>
#         <li> 1. Identify <i>variables of interest</i> in dataset <strong>processed_data.csv</strong></li>
#         <li> 2: Create a <i>working dataset</i> from dataset containing those variables of interest.</li>
#     </ul>
# </details>
#
# <details>
#     <summary><strong>Context</strong></summary>
#     We've downloaded raw data from NCES IPEDS <a href="https://nces.ed.gov/ipeds/use-the-data/"><strong>https://nces.ed.gov/ipeds/use-the-data/</strong></a>. It has been pre-processed slightly for the purposes of this workshop.
#     <li>This notebook will create an analytical file to be used in the 01_Data_Visualization notebook.</li>
#     <li>The pre-processed masterfile contains coordinates of higher education institutions as well as other institutional characteritics.</li>
#     <li>The pre-processed mssterfile also contains graduation rate, demographic, and enrollment statistics.</li>
# </details>

# %%
import pandas as pd
import geopandas as gpd
import geoplot as gplt
import geoplot.crs as gcrs
from pathlib import Path
from tools import tree
from datetime import datetime as dt
today = dt.today().strftime("%d-%b-%y")

today
# Out:
# '19-Apr-20'

# %%
RAW_DATA = Path("../data/raw/")
INTERIM_DATA = Path("../data/interim/")
PROCESSED_DATA = Path("../data/processed/")
FINAL_DATA = Path("../data/final/")
EXTERNAL_DATA = Path("../data/external/")

# %%
tree(PROCESSED_DATA)
# Out:
# + ../data/processed
#     + counties.csv
#     + geodata
#         + tl_2019_us_county.cpg
#         + tl_2019_us_county.dbf
#         + tl_2019_us_county.prj
#         + tl_2019_us_county.shp
#         + tl_2019_us_county.shp.ea.iso.xml
#         + tl_2019_us_county.shp.iso.xml
#         + tl_2019_us_county.shx
#     + institutional_characteristics.csv
#     + processed_data.csv

# %%
data = pd.read_csv(PROCESSED_DATA / 'institutional_characteristics.csv')

# %%
data.head()
# Out:
#                        institution_name   longitude   latitude  \
# 0                Aaniiih Nakoda College -108.757816  48.484196
# 1          Abilene Christian University  -99.709797  32.468943
# 2  Abraham Baldwin Agricultural College  -83.528281  31.481889
# 3            Abraham Lincoln University -118.256726  34.146294
# 4                       Academy College  -93.299809  44.855722
#
#   fips_state_code  total_enrollment  full-time_enrollment  \
# 0         Montana             150.0                 108.0
# 1           Texas            5204.0                3730.0
# 2         Georgia            4291.0                2660.0
# 3      California             217.0                 194.0
# 4       Minnesota              99.0                  81.0
#
#    part-time_enrollment                 control             level
# 0                  42.0                  Public            2-year
# 1                1474.0  Private not-for-profit   4-year or above
# 2                1631.0                  Public   4-year or above
# 3                  23.0      Private for-profit   4-year or above
# 4                  18.0      Private for-profit   4-year or above

# %%
data['share_full-time'] = data['full-time_enrollment'] / data['total_enrollment']

# %%
institutions = gpd.GeoDataFrame(data, geometry = gpd.points_from_xy(data['longitude'], data['latitude']))

# %%
institutions.plot();

# %%
gplt.pointplot(institutions, hue='total_enrollment', legend=True)

# %%
counties = gpd.read_file(PROCESSED_DATA / 'geodata' / 'tl_2019_us_county.shp')

# %%
ax = gplt.polyplot(counties, projection=gcrs.WebMercator(), figsize=(12,12))
gplt.pointplot(institutions, hue='share_full-time', legend = False, ax=ax, scale='share_full-time')

# %% [markdown]
# We can focus on the contiguous states for now. For that we'll use the very simple but very handy package `us`.

# %%
import us

# %% [markdown]
# `us` comes with a lot of useful information.

# %% [markdown]
# You can lookup states even if you have typos in your data

# %%
us.states.lookup('califrnia')
# Out:
# <State:California>

# %% [markdown]
# or just their abbreviation

# %%
us.states.lookup("ca")
# Out:
# <State:California>

# %% [markdown]
# This is a `State` class that comes with a lot of information

# %%
california = us.states.lookup("cailfrnia")

# %%
california.statehood_year
# Out:
# 1850

# %%
california.capital
# Out:
# 'Sacramento'

# %%
california.fips
# Out:
# '06'

# %%
california.is_contiguous
# Out:
# True

# %% [markdown]
# Even official census shapefiles

# %%
california.shapefile_urls()
# Out:
# {'tract': 'https://www2.census.gov/geo/tiger/TIGER2010/TRACT/2010/tl_2010_06_tract10.zip',
#  'cd': 'https://www2.census.gov/geo/tiger/TIGER2010/CD/111/tl_2010_06_cd111.zip',
#  'county': 'https://www2.census.gov/geo/tiger/TIGER2010/COUNTY/2010/tl_2010_06_county10.zip',
#  'state': 'https://www2.census.gov/geo/tiger/TIGER2010/STATE/2010/tl_2010_06_state10.zip',
#  'zcta': 'https://www2.census.gov/geo/tiger/TIGER2010/ZCTA5/2010/tl_2010_06_zcta510.zip',
#  'block': 'https://www2.census.gov/geo/tiger/TIGER2010/TABBLOCK/2010/tl_2010_06_tabblock10.zip',
#  'blockgroup': 'https://www2.census.gov/geo/tiger/TIGER2010/BG/2010/tl_2010_06_bg10.zip'}

# %% [markdown]
# We will use it to filter out non-contiguous states.

# %%
us.STATES_CONTIGUOUS
# Out:
# [<State:Alabama>,
#  <State:Arizona>,
#  <State:Arkansas>,
#  <State:California>,
#  <State:Colorado>,
#  <State:Connecticut>,
#  <State:Delaware>,
#  <State:District of Columbia>,
#  <State:Florida>,
#  <State:Georgia>,
#  <State:Idaho>,
#  <State:Illinois>,
#  <State:Indiana>,
#  <State:Iowa>,
#  <State:Kansas>,
#  <State:Kentucky>,
#  <State:Louisiana>,
#  <State:Maine>,
#  <State:Maryland>,
#  <State:Massachusetts>,
#  <State:Michigan>,
#  <State:Minnesota>,
#  <State:Mississippi>,
#  <State:Missouri>,
#  <State:Montana>,
#  <State:Nebraska>,
#  <State:Nevada>,
#  <State:New Hampshire>,
#  <State:New Jersey>,
#  <State:New Mexico>,
#  <State:New York>,
#  <State:North Carolina>,
#  <State:North Dakota>,
#  <State:Ohio>,
#  <State:Oklahoma>,
#  <State:Oregon>,
#  <State:Pennsylvania>,
#  <State:Rhode Island>,
#  <State:South Carolina>,
#  <State:South Dakota>,
#  <State:Tennessee>,
#  <State:Texas>,
#  <State:Utah>,
#  <State:Vermont>,
#  <State:Virginia>,
#  <State:Washington>,
#  <State:West Virginia>,
#  <State:Wisconsin>,
#  <State:Wyoming>]

# %%
contiguous_fips = [state.fips for state in us.STATES_CONTIGUOUS]

# %%
mask_is_contiguous_counties = counties['STATEFP'].isin(contiguous_fips)

# %%
contiguous_counties = counties[mask_is_contiguous_counties].copy()

# %%
contiguous_counties.head()
# Out:
#   STATEFP COUNTYFP  COUNTYNS  GEOID       NAME          NAMELSAD LSAD CLASSFP  \
# 0      31      039  00835841  31039     Cuming     Cuming County   06      H1
# 1      53      069  01513275  53069  Wahkiakum  Wahkiakum County   06      H1
# 2      35      011  00933054  35011    De Baca    De Baca County   06      H1
# 3      31      109  00835876  31109  Lancaster  Lancaster County   06      H1
# 4      31      129  00835886  31129   Nuckolls   Nuckolls County   06      H1
#
#    MTFCC CSAFP CBSAFP METDIVFP FUNCSTAT       ALAND    AWATER     INTPTLAT  \
# 0  G4020  None   None     None        A  1477652222  10690952  +41.9158651
# 1  G4020  None   None     None        A   680962890  61582307  +46.2946377
# 2  G4020  None   None     None        A  6016819475  29089486  +34.3592729
# 3  G4020   339  30700     None        A  2169270569  22849484  +40.7835474
# 4  G4020  None   None     None        A  1489645188   1718484  +40.1764918
#
#        INTPTLON                                           geometry
# 0  -096.7885168  POLYGON ((-97.01952 42.00410, -97.01952 42.004...
# 1  -123.4244583  POLYGON ((-123.43639 46.23820, -123.44759 46.2...
# 2  -104.3686961  POLYGON ((-104.56739 33.99757, -104.56772 33.9...
# 3  -096.6886584  POLYGON ((-96.91075 40.78494, -96.91075 40.790...
# 4  -098.0468422  POLYGON ((-98.27367 40.08940, -98.27367 40.089...

# %% [markdown]
# we'll need to filter out the institutions in those counties as well.
#
# There's two ways of doing this because our institutions dataframe has the name of the state the institution is in. We can:
# 1. Use this column directly, like we did just now using each state FIPS code
# 2. Create a new column with the state's FIPS code and filter out using that
#
# I'm going to do #2 just to illustrate another functionality of `us` but you should try #1 too.

# %%
institutions.head()
# Out:
#                        institution_name   longitude   latitude  \
# 0                Aaniiih Nakoda College -108.757816  48.484196
# 1          Abilene Christian University  -99.709797  32.468943
# 2  Abraham Baldwin Agricultural College  -83.528281  31.481889
# 3            Abraham Lincoln University -118.256726  34.146294
# 4                       Academy College  -93.299809  44.855722
#
#   fips_state_code  total_enrollment  full-time_enrollment  \
# 0         Montana             150.0                 108.0
# 1           Texas            5204.0                3730.0
# 2         Georgia            4291.0                2660.0
# 3      California             217.0                 194.0
# 4       Minnesota              99.0                  81.0
#
#    part-time_enrollment                 control             level  \
# 0                  42.0                  Public            2-year
# 1                1474.0  Private not-for-profit   4-year or above
# 2                1631.0                  Public   4-year or above
# 3                  23.0      Private for-profit   4-year or above
# 4                  18.0      Private for-profit   4-year or above
#
#    share_full-time                     geometry
# 0         0.720000  POINT (-108.75782 48.48420)
# 1         0.716756   POINT (-99.70980 32.46894)
# 2         0.619902   POINT (-83.52828 31.48189)
# 3         0.894009  POINT (-118.25673 34.14629)
# 4         0.818182   POINT (-93.29981 44.85572)

# %%
institutions['FIPS'] = institutions['fips_state_code'].map(us.states.mapping("name", "fips"))

# %%
institutions.head()
# Out:
#                        institution_name   longitude   latitude  \
# 0                Aaniiih Nakoda College -108.757816  48.484196
# 1          Abilene Christian University  -99.709797  32.468943
# 2  Abraham Baldwin Agricultural College  -83.528281  31.481889
# 3            Abraham Lincoln University -118.256726  34.146294
# 4                       Academy College  -93.299809  44.855722
#
#   fips_state_code  total_enrollment  full-time_enrollment  \
# 0         Montana             150.0                 108.0
# 1           Texas            5204.0                3730.0
# 2         Georgia            4291.0                2660.0
# 3      California             217.0                 194.0
# 4       Minnesota              99.0                  81.0
#
#    part-time_enrollment                 control             level  \
# 0                  42.0                  Public            2-year
# 1                1474.0  Private not-for-profit   4-year or above
# 2                1631.0                  Public   4-year or above
# 3                  23.0      Private for-profit   4-year or above
# 4                  18.0      Private for-profit   4-year or above
#
#    share_full-time                     geometry FIPS
# 0         0.720000  POINT (-108.75782 48.48420)   30
# 1         0.716756   POINT (-99.70980 32.46894)   48
# 2         0.619902   POINT (-83.52828 31.48189)   13
# 3         0.894009  POINT (-118.25673 34.14629)   06
# 4         0.818182   POINT (-93.29981 44.85572)   27

# %%
mask_is_contiguous_institutions = institutions['FIPS'].isin(contiguous_fips)

# %%
contiguous_institutions = institutions[mask_is_contiguous_institutions].copy()

# %%
ax = gplt.polyplot(contiguous_counties, projection=gcrs.WebMercator(), figsize=(12,12), )
gplt.pointplot(contiguous_institutions, hue='share_full-time', legend = False, ax=ax, scale='share_full-time')

# %%
contiguous_counties.head()
# Out:
#   STATEFP COUNTYFP  COUNTYNS  GEOID       NAME          NAMELSAD LSAD CLASSFP  \
# 0      31      039  00835841  31039     Cuming     Cuming County   06      H1
# 1      53      069  01513275  53069  Wahkiakum  Wahkiakum County   06      H1
# 2      35      011  00933054  35011    De Baca    De Baca County   06      H1
# 3      31      109  00835876  31109  Lancaster  Lancaster County   06      H1
# 4      31      129  00835886  31129   Nuckolls   Nuckolls County   06      H1
#
#    MTFCC CSAFP CBSAFP METDIVFP FUNCSTAT       ALAND    AWATER     INTPTLAT  \
# 0  G4020  None   None     None        A  1477652222  10690952  +41.9158651
# 1  G4020  None   None     None        A   680962890  61582307  +46.2946377
# 2  G4020  None   None     None        A  6016819475  29089486  +34.3592729
# 3  G4020   339  30700     None        A  2169270569  22849484  +40.7835474
# 4  G4020  None   None     None        A  1489645188   1718484  +40.1764918
#
#        INTPTLON                                           geometry
# 0  -096.7885168  POLYGON ((-97.01952 42.00410, -97.01952 42.004...
# 1  -123.4244583  POLYGON ((-123.43639 46.23820, -123.44759 46.2...
# 2  -104.3686961  POLYGON ((-104.56739 33.99757, -104.56772 33.9...
# 3  -096.6886584  POLYGON ((-96.91075 40.78494, -96.91075 40.790...
# 4  -098.0468422  POLYGON ((-98.27367 40.08940, -98.27367 40.089...

# %%
county_data = pd.read_csv(PROCESSED_DATA / 'counties.csv')

# %%
county_data.head()
# Out:
#    geoid                     name  universe  white_alone  black_alone  \
# 0   1001  Autauga County, Alabama   55200.0      41412.0      10475.0
# 1   1003  Baldwin County, Alabama  208107.0     172768.0      19529.0
# 2   1005  Barbour County, Alabama   25782.0      11898.0      12199.0
# 3   1007     Bibb County, Alabama   22527.0      16801.0       4974.0
# 4   1009   Blount County, Alabama   57645.0      50232.0        820.0
#
#    american_indian_and_alaska_native  asian_alone  \
# 0                              159.0        568.0
# 1                             1398.0       1668.0
# 2                               63.0         85.0
# 3                                8.0         37.0
# 4                              124.0        198.0
#
#    native_hawaiian_and_pacific_islander  other_alone  two_or_more_races  \
# 0                                   5.0         41.0             1012.0
# 1                                   9.0        410.0             2972.0
# 2                                   1.0         86.0              344.0
# 3                                   0.0          0.0              160.0
# 4                                  18.0        174.0              818.0
#
#    latino_alone  state  county  asians_all  other_all
# 0        1528.0      1       1       573.0     1212.0
# 1        9353.0      1       3      1677.0     4780.0
# 2        1106.0      1       5        86.0      493.0
# 3         547.0      1       7        37.0      168.0
# 4        5261.0      1       9       216.0     1116.0

# %%
county_data['geoid'] = county_data['geoid'].astype("str").str.zfill(5)

# %%
county_data = county_data.set_index("geoid")

# %%
contiguous_counties = contiguous_counties.set_index("GEOID")

# %%
working_df = contiguous_counties.join(county_data, )

# %%
working_df.sample(5).T
# Out:
# GEOID                                                                             04025  \
# STATEFP                                                                              04
# COUNTYFP                                                                            025
# COUNTYNS                                                                       00042809
# NAME                                                                            Yavapai
# NAMELSAD                                                                 Yavapai County
# LSAD                                                                                 06
# CLASSFP                                                                              H1
# MTFCC                                                                             G4020
# CSAFP                                                                              None
# CBSAFP                                                                            39150
# METDIVFP                                                                           None
# FUNCSTAT                                                                              A
# ALAND                                                                       21038727465
# AWATER                                                                         11501576
# INTPTLAT                                                                    +34.6310710
# INTPTLON                                                                   -112.5772247
# geometry                              POLYGON ((-113.333028 34.78858, -113.333013 34...
# name                                                            Yavapai County, Arizona
# universe                                                                         224645
# white_alone                                                                      181227
# black_alone                                                                        1224
# american_indian_and_alaska_native                                                  2659
# asian_alone                                                                        2166
# native_hawaiian_and_pacific_islander                                                191
# other_alone                                                                         132
# two_or_more_races                                                                  4585
# latino_alone                                                                      32461
# state                                                                                 4
# county                                                                               25
# asians_all                                                                         2357
# other_all                                                                          7376
#
# GEOID                                                                             27011  \
# STATEFP                                                                              27
# COUNTYFP                                                                            011
# COUNTYNS                                                                       00659451
# NAME                                                                          Big Stone
# NAMELSAD                                                               Big Stone County
# LSAD                                                                                 06
# CLASSFP                                                                              H1
# MTFCC                                                                             G4020
# CSAFP                                                                              None
# CBSAFP                                                                             None
# METDIVFP                                                                           None
# FUNCSTAT                                                                              A
# ALAND                                                                        1292861685
# AWATER                                                                         74956395
# INTPTLAT                                                                    +45.4199252
# INTPTLON                                                                   -096.4022263
# geometry                              POLYGON ((-96.752865 45.502163, -96.754959 45....
# name                                                        Big Stone County, Minnesota
# universe                                                                           5016
# white_alone                                                                        4892
# black_alone                                                                           2
# american_indian_and_alaska_native                                                     3
# asian_alone                                                                           0
# native_hawaiian_and_pacific_islander                                                  0
# other_alone                                                                           2
# two_or_more_races                                                                    37
# latino_alone                                                                         80
# state                                                                                27
# county                                                                               11
# asians_all                                                                            0
# other_all                                                                            42
#
# GEOID                                                                             34011  \
# STATEFP                                                                              34
# COUNTYFP                                                                            011
# COUNTYNS                                                                       00882275
# NAME                                                                         Cumberland
# NAMELSAD                                                              Cumberland County
# LSAD                                                                                 06
# CLASSFP                                                                              H1
# MTFCC                                                                             G4020
# CSAFP                                                                               428
# CBSAFP                                                                            47220
# METDIVFP                                                                           None
# FUNCSTAT                                                                              A
# ALAND                                                                        1251898273
# AWATER                                                                        503713107
# INTPTLAT                                                                    +39.3284336
# INTPTLON                                                                   -075.1216277
# geometry                              POLYGON ((-75.41118899999999 39.420423, -75.41...
# name                                                      Cumberland County, New Jersey
# universe                                                                         153400
# white_alone                                                                       72033
# black_alone                                                                       27616
# american_indian_and_alaska_native                                                   803
# asian_alone                                                                        2040
# native_hawaiian_and_pacific_islander                                                  0
# other_alone                                                                         135
# two_or_more_races                                                                  4519
# latino_alone                                                                      46254
# state                                                                                34
# county                                                                               11
# asians_all                                                                         2040
# other_all                                                                          5457
#
# GEOID                                                                             17165  \
# STATEFP                                                                              17
# COUNTYFP                                                                            165
# COUNTYNS                                                                       00424283
# NAME                                                                             Saline
# NAMELSAD                                                                  Saline County
# LSAD                                                                                 06
# CLASSFP                                                                              H1
# MTFCC                                                                             G4020
# CSAFP                                                                              None
# CBSAFP                                                                             None
# METDIVFP                                                                           None
# FUNCSTAT                                                                              A
# ALAND                                                                         984170285
# AWATER                                                                         17979016
# INTPTLAT                                                                    +37.7515083
# INTPTLON                                                                   -088.5450236
# geometry                              POLYGON ((-88.70696799999999 37.819783, -88.70...
# name                                                            Saline County, Illinois
# universe                                                                          24231
# white_alone                                                                       22175
# black_alone                                                                         683
# american_indian_and_alaska_native                                                    40
# asian_alone                                                                         185
# native_hawaiian_and_pacific_islander                                                 47
# other_alone                                                                          13
# two_or_more_races                                                                   658
# latino_alone                                                                        430
# state                                                                                17
# county                                                                              165
# asians_all                                                                          232
# other_all                                                                           711
#
# GEOID                                                                             17109
# STATEFP                                                                              17
# COUNTYFP                                                                            109
# COUNTYNS                                                                       01784729
# NAME                                                                          McDonough
# NAMELSAD                                                               McDonough County
# LSAD                                                                                 06
# CLASSFP                                                                              H1
# MTFCC                                                                             G4020
# CSAFP                                                                              None
# CBSAFP                                                                            31380
# METDIVFP                                                                           None
# FUNCSTAT                                                                              A
# ALAND                                                                        1526339596
# AWATER                                                                          2012552
# INTPTLAT                                                                    +40.4558082
# INTPTLON                                                                   -090.6789543
# geometry                              POLYGON ((-90.90733499999999 40.462592, -90.90...
# name                                                         McDonough County, Illinois
# universe                                                                          30875
# white_alone                                                                       27213
# black_alone                                                                        1431
# american_indian_and_alaska_native                                                    55
# asian_alone                                                                         689
# native_hawaiian_and_pacific_islander                                                  0
# other_alone                                                                           0
# two_or_more_races                                                                   652
# latino_alone                                                                        835
# state                                                                                17
# county                                                                              109
# asians_all                                                                          689
# other_all                                                                           707

# %%
working_df['share_white'] = working_df['white_alone'] / working_df['universe']
working_df['share_black'] = working_df['black_alone'] / working_df['universe']
working_df['share_latino'] = working_df['latino_alone'] / working_df['universe']
working_df['share_asian'] = working_df['asian_alone'] / working_df['universe']

# %%
import mapclassify as mc

# %% [markdown]
# http://www.geog.ucsb.edu/~kclarke/Geography183/Lecture06.pdf

# %%
k = 7 
scheme_quantiles = mc.Quantiles(working_df['universe'], k=k)
scheme_fisherjenk = mc.FisherJenks(working_df['universe'], k=k)
scheme_fisherjenksampled = mc.FisherJenksSampled(working_df['universe'].values, k=k)

# %%
scheme_quantiles
# Out:
# Quantiles
#
#          Interval            Count
# ----------------------------------
# [     102.00,     6912.57] |   444
# (    6912.57,    12948.00] |   444
# (   12948.00,    20696.71] |   444
# (   20696.71,    33592.57] |   444
# (   33592.57,    56916.14] |   444
# (   56916.14,   143127.71] |   444
# (  143127.71, 10098052.00] |   444

# %%
scheme_fisherjenk
# Out:
# FisherJenks
#
#          Interval            Count
# ----------------------------------
# [     102.00,   138111.00] |  2651
# (  138111.00,   469116.00] |   313
# (  469116.00,   998684.00] |   100
# (  998684.00,  1761382.00] |    26
# ( 1761382.00,  3302833.00] |    14
# ( 3302833.00,  5223719.00] |     3
# ( 5223719.00, 10098052.00] |     1

# %%
scheme_fisherjenksampled
# Out:
# FisherJenksSampled
#
#          Interval            Count
# ----------------------------------
# [     102.00,    81441.00] |  2425
# (   81441.00,   289564.00] |   450
# (  289564.00,   538347.00] |   110
# (  538347.00,  1046558.00] |    83
# ( 1046558.00,  2163257.00] |    29
# ( 2163257.00,  5223719.00] |    10
# ( 5223719.00, 10098052.00] |     1

# %%
legend_labels = [
    "< 76K",
    "76 - 225K",
    "225 - 450K",
    "450 - 930K",
    "930K - 1.49M",
    "1.49 - 2.38M",
    "2.38 - 10M"
]

# %%
ax = gplt.choropleth(
    working_df, hue='universe', projection=gcrs.AlbersEqualArea(),
    edgecolor='white', linewidth=1,
    cmap='OrRd', legend=True, legend_kwargs={'loc': 'lower left'},
    scheme=scheme_fisherjenksampled,
    figsize=(12,12),
    legend_labels=legend_labels
)

gplt.pointplot(
    contiguous_institutions, 
#     hue='share_full-time', 
    legend = True, 
    ax=ax, 
    scale='total_enrollment',
    limits = (2,15),
    legend_var = 'scale', 
    zorder = 3,
    alpha = .1,
)

# %%
k = 5
voi = 'share_black'
scheme = mc.Quantiles(working_df[voi].values, k = k)

ax = gplt.choropleth(
    working_df, hue=voi, projection=gcrs.AlbersEqualArea(),
    edgecolor='white', linewidth=1,
    cmap='OrRd', legend=True, legend_kwargs={'loc': 'lower left'},
    scheme=scheme,
    figsize=(12,12),
#     legend_labels=legend_labels
)

gplt.pointplot(
    contiguous_institutions, 
#     hue='share_full-time', 
    legend = True, 
    ax=ax, 
    scale='total_enrollment',
    limits = (2,15),
    legend_var = 'scale', 
    zorder = 3,
    alpha = .1,
)

# %%
k = 5
voi = 'share_latino'
scheme = mc.Quantiles(working_df[voi].values, k = k)

ax = gplt.choropleth(
    working_df, hue=voi, projection=gcrs.AlbersEqualArea(),
    edgecolor='white', linewidth=1,
    cmap='OrRd', legend=True, legend_kwargs={'loc': 'lower left'},
    scheme=scheme,
    figsize=(12,12),
#     legend_labels=legend_labels
)

gplt.pointplot(
    contiguous_institutions, 
#     hue='share_full-time', 
    legend = True, 
    ax=ax, 
    scale='total_enrollment',
    limits = (2,15),
    legend_var = 'scale', 
    zorder = 3,
    alpha = .1,
)

# %%
k = 5
voi = 'share_asian'
scheme = mc.Quantiles(working_df[voi].values, k = k)

ax = gplt.choropleth(
    working_df, hue=voi, projection=gcrs.AlbersEqualArea(),
    edgecolor='white', linewidth=1,
    cmap='OrRd', legend=True, legend_kwargs={'loc': 'lower left'},
    scheme=scheme,
    figsize=(12,12),
#     legend_labels=legend_labels
)

gplt.pointplot(
    contiguous_institutions, 
#     hue='share_full-time', 
    legend = True, 
    ax=ax, 
    scale='total_enrollment',
    limits = (2,15),
    legend_var = 'scale', 
    zorder = 3,
    alpha = .1,
)

# %%
k = 5
voi = 'share_white'
scheme = mc.Quantiles(working_df[voi].values, k = k)

ax = gplt.choropleth(
    working_df, hue=voi, projection=gcrs.AlbersEqualArea(),
    edgecolor='white', linewidth=1,
    cmap='OrRd', legend=True, legend_kwargs={'loc': 'lower left'},
    scheme=scheme,
    figsize=(12,12),
#     legend_labels=legend_labels
)

gplt.pointplot(
    contiguous_institutions, 
#     hue='share_full-time', 
    legend = True, 
    ax=ax, 
    scale='total_enrollment',
    limits = (2,15),
    legend_var = 'scale', 
    zorder = 3,
    alpha = .1,
)
