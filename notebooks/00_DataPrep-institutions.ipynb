# %% [markdown]
# # GeoSpatial Public Policy Analysis - PyCon 2020
# #### A repository containing the materials for the tutorial Geospatial Public Policy Analysis with GeoPandas for PyCon 2020. To be delivered virtually.
#
# <details>
#     <summary><strong>Goal</strong></summary>
#     The goal of this notebook is to process NCES IPEDS tabular data into an analytical file (subset) that will be used in another notebook to visualize education deserts.
#     <ul>
#         <li> Measurable goals for this notebook:</li>
#         <li> 1. Identify <i>variables of interest</i> in dataset <strong>processed_data.csv</strong></li>
#         <li> 2: Create a <i>working dataset</i> from dataset containing those variables of interest.</li>
#     </ul>
# </details>
#
# <details>
#     <summary><strong>Context</strong></summary>
#     We've downloaded raw data from NCES IPEDS <a href="https://nces.ed.gov/ipeds/use-the-data/"><strong>https://nces.ed.gov/ipeds/use-the-data/</strong></a>. It has been pre-processed slightly for the purposes of this workshop.
#     <li>This notebook will create an analytical file to be used in the 01_Data_Visualization notebook.</li>
#     <li>The pre-processed masterfile contains coordinates of higher education institutions as well as other institutional characteritics.</li>
#     <li>The pre-processed mssterfile also contains graduation rate, demographic, and enrollment statistics.</li>
# </details>

# %%
import pandas as pd
from pathlib import Path
from tools import tree
from datetime import datetime as dt
today = dt.today().strftime("%d-%b-%y")

today
# Out:
# '14-Apr-20'

# %%
RAW_DATA = Path("../data/raw/")
INTERIM_DATA = Path("../data/interim/")
PROCESSED_DATA = Path("../data/processed/")
FINAL_DATA = Path("../data/final/")
EXTERNAL_DATA = Path("../data/external/")

# %%
tree(PROCESSED_DATA)
# Out:
# + ../data/processed
#     + processed_data.csv

# %%
data = pd.read_csv(PROCESSED_DATA / 'processed_data.csv')
data.head().T
# Out:
#                                                                                                     0  \
# unitid                                                                                         180203
# institution_name                                                               Aaniiih Nakoda College
# fips_state_code                                                                               Montana
# sector                                                                                 Public, 2-year
# institutional_category                              Degree-granting, associate's and certificates ...
# street_address                                                            269 Blackfeet Avenue Agency
# institution_name_alias
# institution_name.1                                                             Aaniiih Nakoda College
# longitude                                                                                    -108.758
# latitude                                                                                      48.4842
# historically_black_college_or_university                                                           No
# tribal_college                                                                                    Yes
# percent_admitted_total                                                                            NaN
# percent_admitted_women                                                                            NaN
# percent_admitted_men                                                                              NaN
# percent_total_enrollment_american_indian_or_ala...                                                 83
# percent_total_enrollment_asian-native_hawaiian-...                                                  0
# percent_total_enrollment_asian                                                                      0
# percent_total_enrollment_native_hawaiian_or_oth...                                                  0
# percent_total_enrollment_black_or_african_american                                                  0
# percent_total_enrollment_hispanic-latino                                                            1
# percent_total_enrollment_white                                                                     16
# percent_total_enrollment_race-ethnicity_unknown                                                     0
# percent_total_enrollment_nonresident_alien                                                          0
# percent_total_enrollment_multirace                                                                  0
# percent_total_enrollment_women                                                                     60
# total_enrollment                                                                                  150
# full-time_enrollment                                                                              108
# part-time_enrollment                                                                               42
# gradrate_total_cohort                                                                              32
# gradrate_men                                                                                       31
# gradrate_women                                                                                     33
# gradrate_bachelor_degree_4_years_total                                                            NaN
# gradrate_bachelor_degree_5_years_total                                                            NaN
# gradrate_bachelor_degree_6_years_total                                                            NaN
# gradrate_bachelor_degree_6_years_men                                                              NaN
# gradrate_bachelor_degree_6_years_women                                                            NaN
# gradrate_bachelor_degree_6_years_american_india...                                                NaN
# gradrate_bachelor_degree_6_years_asian-native_h...                                                NaN
# gradrate_bachelor_degree_6_years_asian                                                            NaN
# gradrate_bachelor_degree_6_years_native_hawaiia...                                                NaN
# gradrate_bachelor_degree_6_years_black_non-hisp...                                                NaN
# gradrate_bachelor_degree_6_years_hispanic                                                         NaN
# gradrate_bachelor_degree_6_years_white_non-hisp...                                                NaN
# gradrate_bachelor_degree_6_years_multirace                                                        NaN
# gradrate_bachelor_degree_6_years_nonresident_alien                                                NaN
# gradrate_bachelor_degree_6_years_race-ethnicity...                                                NaN
# pell_grant_recipients_overall_gradrate_150_perc...                                                  0
# pell_grant_recipients_bachelor_degree_rate_6_years                                                NaN
#
#                                                                                                     1  \
# unitid                                                                                         222178
# institution_name                                                         Abilene Christian University
# fips_state_code                                                                                 Texas
# sector                                                        Private not-for-profit, 4-year or above
# institutional_category                              Degree-granting, primarily baccalaureate or above
# street_address
# institution_name_alias
# institution_name.1                                                       Abilene Christian University
# longitude                                                                                    -99.7098
# latitude                                                                                      32.4689
# historically_black_college_or_university                                                           No
# tribal_college                                                                                     No
# percent_admitted_total                                                                             57
# percent_admitted_women                                                                             59
# percent_admitted_men                                                                               54
# percent_total_enrollment_american_indian_or_ala...                                                  0
# percent_total_enrollment_asian-native_hawaiian-...                                                  1
# percent_total_enrollment_asian                                                                      1
# percent_total_enrollment_native_hawaiian_or_oth...                                                  0
# percent_total_enrollment_black_or_african_american                                                 13
# percent_total_enrollment_hispanic-latino                                                           17
# percent_total_enrollment_white                                                                     60
# percent_total_enrollment_race-ethnicity_unknown                                                     1
# percent_total_enrollment_nonresident_alien                                                          3
# percent_total_enrollment_multirace                                                                  4
# percent_total_enrollment_women                                                                     63
# total_enrollment                                                                                 5204
# full-time_enrollment                                                                             3730
# part-time_enrollment                                                                             1474
# gradrate_total_cohort                                                                              67
# gradrate_men                                                                                       63
# gradrate_women                                                                                     69
# gradrate_bachelor_degree_4_years_total                                                             53
# gradrate_bachelor_degree_5_years_total                                                             66
# gradrate_bachelor_degree_6_years_total                                                             67
# gradrate_bachelor_degree_6_years_men                                                               64
# gradrate_bachelor_degree_6_years_women                                                             69
# gradrate_bachelor_degree_6_years_american_india...                                                 75
# gradrate_bachelor_degree_6_years_asian-native_h...                                                 14
# gradrate_bachelor_degree_6_years_asian                                                             14
# gradrate_bachelor_degree_6_years_native_hawaiia...                                                NaN
# gradrate_bachelor_degree_6_years_black_non-hisp...                                                 53
# gradrate_bachelor_degree_6_years_hispanic                                                          52
# gradrate_bachelor_degree_6_years_white_non-hisp...                                                 72
# gradrate_bachelor_degree_6_years_multirace                                                         61
# gradrate_bachelor_degree_6_years_nonresident_alien                                                 79
# gradrate_bachelor_degree_6_years_race-ethnicity...                                                NaN
# pell_grant_recipients_overall_gradrate_150_perc...                                                 53
# pell_grant_recipients_bachelor_degree_rate_6_years                                                 53
#
#                                                                                                     2  \
# unitid                                                                                         138558
# institution_name                                                 Abraham Baldwin Agricultural College
# fips_state_code                                                                               Georgia
# sector                                                                        Public, 4-year or above
# institutional_category                              Degree-granting, not primarily baccalaureate o...
# street_address                                                                         2802 Moore Hwy
# institution_name_alias                                                                           ABAC
# institution_name.1                                               Abraham Baldwin Agricultural College
# longitude                                                                                    -83.5283
# latitude                                                                                      31.4819
# historically_black_college_or_university                                                           No
# tribal_college                                                                                     No
# percent_admitted_total                                                                             69
# percent_admitted_women                                                                             64
# percent_admitted_men                                                                               76
# percent_total_enrollment_american_indian_or_ala...                                                  0
# percent_total_enrollment_asian-native_hawaiian-...                                                  1
# percent_total_enrollment_asian                                                                      1
# percent_total_enrollment_native_hawaiian_or_oth...                                                  0
# percent_total_enrollment_black_or_african_american                                                 11
# percent_total_enrollment_hispanic-latino                                                            6
# percent_total_enrollment_white                                                                     79
# percent_total_enrollment_race-ethnicity_unknown                                                     0
# percent_total_enrollment_nonresident_alien                                                          1
# percent_total_enrollment_multirace                                                                  1
# percent_total_enrollment_women                                                                     57
# total_enrollment                                                                                 4291
# full-time_enrollment                                                                             2660
# part-time_enrollment                                                                             1631
# gradrate_total_cohort                                                                              22
# gradrate_men                                                                                       23
# gradrate_women                                                                                     21
# gradrate_bachelor_degree_4_years_total                                                             11
# gradrate_bachelor_degree_5_years_total                                                             23
# gradrate_bachelor_degree_6_years_total                                                             25
# gradrate_bachelor_degree_6_years_men                                                               26
# gradrate_bachelor_degree_6_years_women                                                             22
# gradrate_bachelor_degree_6_years_american_india...                                                NaN
# gradrate_bachelor_degree_6_years_asian-native_h...                                                  0
# gradrate_bachelor_degree_6_years_asian                                                              0
# gradrate_bachelor_degree_6_years_native_hawaiia...                                                NaN
# gradrate_bachelor_degree_6_years_black_non-hisp...                                                 43
# gradrate_bachelor_degree_6_years_hispanic                                                           0
# gradrate_bachelor_degree_6_years_white_non-hisp...                                                 23
# gradrate_bachelor_degree_6_years_multirace                                                        NaN
# gradrate_bachelor_degree_6_years_nonresident_alien                                                100
# gradrate_bachelor_degree_6_years_race-ethnicity...                                                NaN
# pell_grant_recipients_overall_gradrate_150_perc...                                                 18
# pell_grant_recipients_bachelor_degree_rate_6_years                                                 22
#
#                                                                                                     3  \
# unitid                                                                                         488031
# institution_name                                                           Abraham Lincoln University
# fips_state_code                                                                            California
# sector                                                            Private for-profit, 4-year or above
# institutional_category                              Degree-granting, primarily baccalaureate or above
# street_address                                                           100 West Broadway  Suite 600
# institution_name_alias
# institution_name.1                                                         Abraham Lincoln University
# longitude                                                                                    -118.257
# latitude                                                                                      34.1463
# historically_black_college_or_university                                                           No
# tribal_college                                                                                     No
# percent_admitted_total                                                                            NaN
# percent_admitted_women                                                                            NaN
# percent_admitted_men                                                                              NaN
# percent_total_enrollment_american_indian_or_ala...                                                  1
# percent_total_enrollment_asian-native_hawaiian-...                                                 11
# percent_total_enrollment_asian                                                                     10
# percent_total_enrollment_native_hawaiian_or_oth...                                                  1
# percent_total_enrollment_black_or_african_american                                                 12
# percent_total_enrollment_hispanic-latino                                                           14
# percent_total_enrollment_white                                                                     38
# percent_total_enrollment_race-ethnicity_unknown                                                    22
# percent_total_enrollment_nonresident_alien                                                          0
# percent_total_enrollment_multirace                                                                  2
# percent_total_enrollment_women                                                                     52
# total_enrollment                                                                                  217
# full-time_enrollment                                                                              194
# part-time_enrollment                                                                               23
# gradrate_total_cohort                                                                             NaN
# gradrate_men                                                                                      NaN
# gradrate_women                                                                                    NaN
# gradrate_bachelor_degree_4_years_total                                                            NaN
# gradrate_bachelor_degree_5_years_total                                                            NaN
# gradrate_bachelor_degree_6_years_total                                                            NaN
# gradrate_bachelor_degree_6_years_men                                                              NaN
# gradrate_bachelor_degree_6_years_women                                                            NaN
# gradrate_bachelor_degree_6_years_american_india...                                                NaN
# gradrate_bachelor_degree_6_years_asian-native_h...                                                NaN
# gradrate_bachelor_degree_6_years_asian                                                            NaN
# gradrate_bachelor_degree_6_years_native_hawaiia...                                                NaN
# gradrate_bachelor_degree_6_years_black_non-hisp...                                                NaN
# gradrate_bachelor_degree_6_years_hispanic                                                         NaN
# gradrate_bachelor_degree_6_years_white_non-hisp...                                                NaN
# gradrate_bachelor_degree_6_years_multirace                                                        NaN
# gradrate_bachelor_degree_6_years_nonresident_alien                                                NaN
# gradrate_bachelor_degree_6_years_race-ethnicity...                                                NaN
# pell_grant_recipients_overall_gradrate_150_perc...                                                NaN
# pell_grant_recipients_bachelor_degree_rate_6_years                                                NaN
#
#                                                                                                     4
# unitid                                                                                         172866
# institution_name                                                                      Academy College
# fips_state_code                                                                             Minnesota
# sector                                                            Private for-profit, 4-year or above
# institutional_category                              Degree-granting, not primarily baccalaureate o...
# street_address                                                         1600 W. 82nd Street  Suite 100
# institution_name_alias
# institution_name.1                                                                    Academy College
# longitude                                                                                    -93.2998
# latitude                                                                                      44.8557
# historically_black_college_or_university                                                           No
# tribal_college                                                                                     No
# percent_admitted_total                                                                            NaN
# percent_admitted_women                                                                            NaN
# percent_admitted_men                                                                              NaN
# percent_total_enrollment_american_indian_or_ala...                                                  0
# percent_total_enrollment_asian-native_hawaiian-...                                                  9
# percent_total_enrollment_asian                                                                      9
# percent_total_enrollment_native_hawaiian_or_oth...                                                  0
# percent_total_enrollment_black_or_african_american                                                 10
# percent_total_enrollment_hispanic-latino                                                            5
# percent_total_enrollment_white                                                                     61
# percent_total_enrollment_race-ethnicity_unknown                                                    14
# percent_total_enrollment_nonresident_alien                                                          0
# percent_total_enrollment_multirace                                                                  1
# percent_total_enrollment_women                                                                     13
# total_enrollment                                                                                   99
# full-time_enrollment                                                                               81
# part-time_enrollment                                                                               18
# gradrate_total_cohort                                                                               0
# gradrate_men                                                                                        0
# gradrate_women                                                                                    NaN
# gradrate_bachelor_degree_4_years_total                                                            NaN
# gradrate_bachelor_degree_5_years_total                                                            NaN
# gradrate_bachelor_degree_6_years_total                                                            NaN
# gradrate_bachelor_degree_6_years_men                                                              NaN
# gradrate_bachelor_degree_6_years_women                                                            NaN
# gradrate_bachelor_degree_6_years_american_india...                                                NaN
# gradrate_bachelor_degree_6_years_asian-native_h...                                                NaN
# gradrate_bachelor_degree_6_years_asian                                                            NaN
# gradrate_bachelor_degree_6_years_native_hawaiia...                                                NaN
# gradrate_bachelor_degree_6_years_black_non-hisp...                                                NaN
# gradrate_bachelor_degree_6_years_hispanic                                                         NaN
# gradrate_bachelor_degree_6_years_white_non-hisp...                                                NaN
# gradrate_bachelor_degree_6_years_multirace                                                        NaN
# gradrate_bachelor_degree_6_years_nonresident_alien                                                NaN
# gradrate_bachelor_degree_6_years_race-ethnicity...                                                NaN
# pell_grant_recipients_overall_gradrate_150_perc...                                                  0
# pell_grant_recipients_bachelor_degree_rate_6_years                                                NaN

# %% [markdown]
# # Variables of interest
#
# There is a lot of variables here. Some are demographic (i.e. `percent_total_enrollment_hispanic-latino`), others are related to graduation rates (`gradrate_*`) and others are institutional characteristics like the name, address, or state an institution is in.
#
# To focus our research we need to choose one topic to tackle at a time. In this case we want to look at the equity implications of education deserts. We will revisit this dataset later to grab more charactersitics related to each higher education institution but for right now we only need the basics:
# 1. Name
# 2. Location (longitude and latitude, state)
# 3. Sector (public vs private, 2- vs 4-year)
# 4. Size (total enrollment, full- and part-time)

# %%
voi = [
    'institution_name',
    'longitude',
    'latitude',
    'fips_state_code',
    'sector',
    'total_enrollment',
    'full-time_enrollment',
    'part-time_enrollment',
]

# %%
data[voi].head()
# Out:
#                        institution_name   longitude   latitude  \
# 0                Aaniiih Nakoda College -108.757816  48.484196
# 1          Abilene Christian University  -99.709797  32.468943
# 2  Abraham Baldwin Agricultural College  -83.528281  31.481889
# 3            Abraham Lincoln University -118.256726  34.146294
# 4                       Academy College  -93.299809  44.855722
#
#   fips_state_code                                   sector  total_enrollment  \
# 0         Montana                           Public, 2-year             150.0
# 1           Texas  Private not-for-profit, 4-year or above            5204.0
# 2         Georgia                  Public, 4-year or above            4291.0
# 3      California      Private for-profit, 4-year or above             217.0
# 4       Minnesota      Private for-profit, 4-year or above              99.0
#
#    full-time_enrollment  part-time_enrollment
# 0                 108.0                  42.0
# 1                3730.0                1474.0
# 2                2660.0                1631.0
# 3                 194.0                  23.0
# 4                  81.0                  18.0

# %%
working_data = data[voi].copy()

# %% [markdown]
# Now you'll notice sector is prividing actually 2 pieces of information: private vs public, 2- vs 4-year status. We should split those up.

# %%
working_data['sector'].str.split(',', expand = True)
# Out:
#                            0                 1
# 0                     Public            2-year
# 1     Private not-for-profit   4-year or above
# 2                     Public   4-year or above
# 3         Private for-profit   4-year or above
# 4         Private for-profit   4-year or above
# ...                      ...               ...
# 3746                  Public   4-year or above
# 3747      Private for-profit            2-year
# 3748      Private for-profit            2-year
# 3749                  Public            2-year
# 3750                  Public            2-year
#
# [3751 rows x 2 columns]

# %% [markdown]
# We'll call those the `control` and `level` of the institution.

# %%
working_data['control'] = working_data['sector'].str.split(',', expand = True)[0]
working_data['level'] = working_data['sector'].str.split(',', expand = True)[1]

# %%
working_data.head()
# Out:
#                        institution_name   longitude   latitude  \
# 0                Aaniiih Nakoda College -108.757816  48.484196
# 1          Abilene Christian University  -99.709797  32.468943
# 2  Abraham Baldwin Agricultural College  -83.528281  31.481889
# 3            Abraham Lincoln University -118.256726  34.146294
# 4                       Academy College  -93.299809  44.855722
#
#   fips_state_code                                   sector  total_enrollment  \
# 0         Montana                           Public, 2-year             150.0
# 1           Texas  Private not-for-profit, 4-year or above            5204.0
# 2         Georgia                  Public, 4-year or above            4291.0
# 3      California      Private for-profit, 4-year or above             217.0
# 4       Minnesota      Private for-profit, 4-year or above              99.0
#
#    full-time_enrollment  part-time_enrollment                 control  \
# 0                 108.0                  42.0                  Public
# 1                3730.0                1474.0  Private not-for-profit
# 2                2660.0                1631.0                  Public
# 3                 194.0                  23.0      Private for-profit
# 4                  81.0                  18.0      Private for-profit
#
#               level
# 0            2-year
# 1   4-year or above
# 2   4-year or above
# 3   4-year or above
# 4   4-year or above

# %% [markdown]
# Now that we don't need the `sector` column we can `.drop` it.

# %%
working_data = working_data.drop(columns = ['sector'])

# %% [markdown]
# Note: you can also do
# ```python
# working_data.drop(columns = ['sector'], inplace = True)
# ```
# but I once saw a talk by Marc Garcia (pandas core dev) where he said we shouldn't do that because some internal stuff in pandas. 🤷

# %%
working_data.head()
# Out:
#                        institution_name   longitude   latitude  \
# 0                Aaniiih Nakoda College -108.757816  48.484196
# 1          Abilene Christian University  -99.709797  32.468943
# 2  Abraham Baldwin Agricultural College  -83.528281  31.481889
# 3            Abraham Lincoln University -118.256726  34.146294
# 4                       Academy College  -93.299809  44.855722
#
#   fips_state_code  total_enrollment  full-time_enrollment  \
# 0         Montana             150.0                 108.0
# 1           Texas            5204.0                3730.0
# 2         Georgia            4291.0                2660.0
# 3      California             217.0                 194.0
# 4       Minnesota              99.0                  81.0
#
#    part-time_enrollment                 control             level
# 0                  42.0                  Public            2-year
# 1                1474.0  Private not-for-profit   4-year or above
# 2                1631.0                  Public   4-year or above
# 3                  23.0      Private for-profit   4-year or above
# 4                  18.0      Private for-profit   4-year or above

# %% [markdown]
# ***
# Check-point!
#
# We have all the necessary variables from this dataset. Let's save this subset for later use.

# %%
working_data.to_csv(PROCESSED_DATA / 'institutional_characteristics.csv', encoding = 'utf-8', index = False)
