# %% [markdown]
# # GeoSpatial Public Policy Analysis - PyCon 2020
# #### A repository containing the materials for the tutorial Geospatial Public Policy Analysis with GeoPandas for PyCon 2020. To be delivered virtually.
#
# <details>
#     <summary><strong>Goal</strong></summary>
#     The goal of this notebook is to process NCES IPEDS tabular data into an analytical file (subset) that will be used in another notebook to visualize education deserts.
#     <ul>
#         <li> Measurable goals for this notebook:</li>
#         <li> 1. Identify <i>variables of interest</i> in dataset <strong>processed_data.csv</strong></li>
#         <li> 2: Create a <i>working dataset</i> from dataset containing those variables of interest.</li>
#     </ul>
# </details>
#
# <details>
#     <summary><strong>Context</strong></summary>
#     We've downloaded raw data from NCES IPEDS <a href="https://nces.ed.gov/ipeds/use-the-data/"><strong>https://nces.ed.gov/ipeds/use-the-data/</strong></a>. It has been pre-processed slightly for the purposes of this workshop.
#     <li>This notebook will create an analytical file to be used in the 01_Data_Visualization notebook.</li>
#     <li>The pre-processed masterfile contains coordinates of higher education institutions as well as other institutional characteritics.</li>
#     <li>The pre-processed mssterfile also contains graduation rate, demographic, and enrollment statistics.</li>
# </details>

# %%
import pandas as pd
from pathlib import Path
from tools import tree
from datetime import datetime as dt
today = dt.today().strftime("%d-%b-%y")

today
# Out:
# '14-Apr-20'

# %%
RAW_DATA = Path("../data/raw/")
INTERIM_DATA = Path("../data/interim/")
PROCESSED_DATA = Path("../data/processed/")
FINAL_DATA = Path("../data/final/")
EXTERNAL_DATA = Path("../data/external/")

# %%
tree(EXTERNAL_DATA)
# Out:
# + ../data/external
#     + 4-8-2020---748.zip
#     + processed
#             + acs5_2018_race_counties-checkpoint.csv
#         + acs5_2018_race_counties.csv
#     + raw
#         + acs5_2018_race_counties.csv

# %%
data = pd.read_csv(EXTERNAL_DATA / 'processed' / 'acs5_2018_race_counties.csv')
data.head().T
# Out:
#                                                                           0  \
# geoid                                                                  1001
# name                                                Autauga County, Alabama
# universe                                                              55200
# universe_annotation                                                     NaN
# universe_moe                                                   -5.55556e+08
# universe_moe_annotation                                               *****
# white_alone                                                           41412
# white_alone_annotation                                                  NaN
# white_alone_moe                                                          59
# white_alone_moe_annotation                                              NaN
# black_alone                                                           10475
# black_alone_annotation                                                  NaN
# black_alone_moe                                                         212
# black_alone_moe_annotation                                              NaN
# american_indian_and_alaska_native                                       159
# american_indian_and_alaska_native_annotation                            NaN
# american_indian_and_alaska_native_moe                                    68
# american_indian_and_alaska_native_moe_annotation                        NaN
# asian_alone                                                             568
# asian_alone_annotation                                                  NaN
# asian_alone_moe                                                         166
# asian_alone_moe_annotation                                              NaN
# native_hawaiian_and_pacific_islander                                      5
# native_hawaiian_and_pacific_islander_annotation                         NaN
# native_hawaiian_and_pacific_islander_moe                                 11
# native_hawaiian_and_pacific_islander_moe_annota...                      NaN
# other_alone                                                              41
# other_alone_annotation                                                  NaN
# other_alone_moe                                                          59
# other_alone_moe_annotation                                              NaN
# two_or_more_races                                                      1012
# two_or_more_races_annotation                                            NaN
# two_or_more_races_moe                                                   251
# two_or_more_races_moe_annotation                                        NaN
# latino_alone                                                           1528
# latino_alone_annotation                                                 NaN
# latino_alone_moe                                               -5.55556e+08
# latino_alone_moe_annotation                                           *****
# state                                                                     1
# county                                                                    1
# asians_all                                                              573
# asians_all_moe                                                      166.364
# other_all                                                              1212
# other_all_moe                                                       266.657
#
#                                                                           1  \
# geoid                                                                  1003
# name                                                Baldwin County, Alabama
# universe                                                             208107
# universe_annotation                                                     NaN
# universe_moe                                                   -5.55556e+08
# universe_moe_annotation                                               *****
# white_alone                                                          172768
# white_alone_annotation                                                  NaN
# white_alone_moe                                                         227
# white_alone_moe_annotation                                              NaN
# black_alone                                                           19529
# black_alone_annotation                                                  NaN
# black_alone_moe                                                         317
# black_alone_moe_annotation                                              NaN
# american_indian_and_alaska_native                                      1398
# american_indian_and_alaska_native_annotation                            NaN
# american_indian_and_alaska_native_moe                                   315
# american_indian_and_alaska_native_moe_annotation                        NaN
# asian_alone                                                            1668
# asian_alone_annotation                                                  NaN
# asian_alone_moe                                                         360
# asian_alone_moe_annotation                                              NaN
# native_hawaiian_and_pacific_islander                                      9
# native_hawaiian_and_pacific_islander_annotation                         NaN
# native_hawaiian_and_pacific_islander_moe                                 13
# native_hawaiian_and_pacific_islander_moe_annota...                      NaN
# other_alone                                                             410
# other_alone_annotation                                                  NaN
# other_alone_moe                                                         288
# other_alone_moe_annotation                                              NaN
# two_or_more_races                                                      2972
# two_or_more_races_annotation                                            NaN
# two_or_more_races_moe                                                   585
# two_or_more_races_moe_annotation                                        NaN
# latino_alone                                                           9353
# latino_alone_annotation                                                 NaN
# latino_alone_moe                                               -5.55556e+08
# latino_alone_moe_annotation                                           *****
# state                                                                     1
# county                                                                    3
# asians_all                                                             1677
# asians_all_moe                                                      360.235
# other_all                                                              4780
# other_all_moe                                                       724.151
#
#                                                                           2  \
# geoid                                                                  1005
# name                                                Barbour County, Alabama
# universe                                                              25782
# universe_annotation                                                     NaN
# universe_moe                                                   -5.55556e+08
# universe_moe_annotation                                               *****
# white_alone                                                           11898
# white_alone_annotation                                                  NaN
# white_alone_moe                                                          22
# white_alone_moe_annotation                                              NaN
# black_alone                                                           12199
# black_alone_annotation                                                  NaN
# black_alone_moe                                                         184
# black_alone_moe_annotation                                              NaN
# american_indian_and_alaska_native                                        63
# american_indian_and_alaska_native_annotation                            NaN
# american_indian_and_alaska_native_moe                                    40
# american_indian_and_alaska_native_moe_annotation                        NaN
# asian_alone                                                              85
# asian_alone_annotation                                                  NaN
# asian_alone_moe                                                          38
# asian_alone_moe_annotation                                              NaN
# native_hawaiian_and_pacific_islander                                      1
# native_hawaiian_and_pacific_islander_annotation                         NaN
# native_hawaiian_and_pacific_islander_moe                                  3
# native_hawaiian_and_pacific_islander_moe_annota...                      NaN
# other_alone                                                              86
# other_alone_annotation                                                  NaN
# other_alone_moe                                                          69
# other_alone_moe_annotation                                              NaN
# two_or_more_races                                                       344
# two_or_more_races_annotation                                            NaN
# two_or_more_races_moe                                                   161
# two_or_more_races_moe_annotation                                        NaN
# latino_alone                                                           1106
# latino_alone_annotation                                                 NaN
# latino_alone_moe                                               -5.55556e+08
# latino_alone_moe_annotation                                           *****
# state                                                                     1
# county                                                                    5
# asians_all                                                               86
# asians_all_moe                                                      38.1182
# other_all                                                               493
# other_all_moe                                                       179.672
#
#                                                                        3  \
# geoid                                                               1007
# name                                                Bibb County, Alabama
# universe                                                           22527
# universe_annotation                                                  NaN
# universe_moe                                                -5.55556e+08
# universe_moe_annotation                                            *****
# white_alone                                                        16801
# white_alone_annotation                                               NaN
# white_alone_moe                                                       22
# white_alone_moe_annotation                                           NaN
# black_alone                                                         4974
# black_alone_annotation                                               NaN
# black_alone_moe                                                       97
# black_alone_moe_annotation                                           NaN
# american_indian_and_alaska_native                                      8
# american_indian_and_alaska_native_annotation                         NaN
# american_indian_and_alaska_native_moe                                 16
# american_indian_and_alaska_native_moe_annotation                     NaN
# asian_alone                                                           37
# asian_alone_annotation                                               NaN
# asian_alone_moe                                                       54
# asian_alone_moe_annotation                                           NaN
# native_hawaiian_and_pacific_islander                                   0
# native_hawaiian_and_pacific_islander_annotation                      NaN
# native_hawaiian_and_pacific_islander_moe                              22
# native_hawaiian_and_pacific_islander_moe_annota...                   NaN
# other_alone                                                            0
# other_alone_annotation                                               NaN
# other_alone_moe                                                       22
# other_alone_moe_annotation                                           NaN
# two_or_more_races                                                    160
# two_or_more_races_annotation                                         NaN
# two_or_more_races_moe                                                 89
# two_or_more_races_moe_annotation                                     NaN
# latino_alone                                                         547
# latino_alone_annotation                                              NaN
# latino_alone_moe                                            -5.55556e+08
# latino_alone_moe_annotation                                        *****
# state                                                                  1
# county                                                                 7
# asians_all                                                            37
# asians_all_moe                                                   58.3095
# other_all                                                            168
# other_all_moe                                                    93.0645
#
#                                                                          4
# geoid                                                                 1009
# name                                                Blount County, Alabama
# universe                                                             57645
# universe_annotation                                                    NaN
# universe_moe                                                  -5.55556e+08
# universe_moe_annotation                                              *****
# white_alone                                                          50232
# white_alone_annotation                                                 NaN
# white_alone_moe                                                        229
# white_alone_moe_annotation                                             NaN
# black_alone                                                            820
# black_alone_annotation                                                 NaN
# black_alone_moe                                                        159
# black_alone_moe_annotation                                             NaN
# american_indian_and_alaska_native                                      124
# american_indian_and_alaska_native_annotation                           NaN
# american_indian_and_alaska_native_moe                                   67
# american_indian_and_alaska_native_moe_annotation                       NaN
# asian_alone                                                            198
# asian_alone_annotation                                                 NaN
# asian_alone_moe                                                         33
# asian_alone_moe_annotation                                             NaN
# native_hawaiian_and_pacific_islander                                    18
# native_hawaiian_and_pacific_islander_annotation                        NaN
# native_hawaiian_and_pacific_islander_moe                                32
# native_hawaiian_and_pacific_islander_moe_annota...                     NaN
# other_alone                                                            174
# other_alone_annotation                                                 NaN
# other_alone_moe                                                        229
# other_alone_moe_annotation                                             NaN
# two_or_more_races                                                      818
# two_or_more_races_annotation                                           NaN
# two_or_more_races_moe                                                  166
# two_or_more_races_moe_annotation                                       NaN
# latino_alone                                                          5261
# latino_alone_annotation                                                NaN
# latino_alone_moe                                              -5.55556e+08
# latino_alone_moe_annotation                                          *****
# state                                                                    1
# county                                                                   9
# asians_all                                                             216
# asians_all_moe                                                     45.9674
# other_all                                                             1116
# other_all_moe                                                      290.665

# %%
voi = [col for col in data.columns if "moe" not in col and "annotation" not in col]
voi
# Out:
# ['geoid',
#  'name',
#  'universe',
#  'white_alone',
#  'black_alone',
#  'american_indian_and_alaska_native',
#  'asian_alone',
#  'native_hawaiian_and_pacific_islander',
#  'other_alone',
#  'two_or_more_races',
#  'latino_alone',
#  'state',
#  'county',
#  'asians_all',
#  'other_all']

# %%
working_data = data[voi].copy()

# %%
working_data.head().T
# Out:
#                                                             0  \
# geoid                                                    1001
# name                                  Autauga County, Alabama
# universe                                                55200
# white_alone                                             41412
# black_alone                                             10475
# american_indian_and_alaska_native                         159
# asian_alone                                               568
# native_hawaiian_and_pacific_islander                        5
# other_alone                                                41
# two_or_more_races                                        1012
# latino_alone                                             1528
# state                                                       1
# county                                                      1
# asians_all                                                573
# other_all                                                1212
#
#                                                             1  \
# geoid                                                    1003
# name                                  Baldwin County, Alabama
# universe                                               208107
# white_alone                                            172768
# black_alone                                             19529
# american_indian_and_alaska_native                        1398
# asian_alone                                              1668
# native_hawaiian_and_pacific_islander                        9
# other_alone                                               410
# two_or_more_races                                        2972
# latino_alone                                             9353
# state                                                       1
# county                                                      3
# asians_all                                               1677
# other_all                                                4780
#
#                                                             2  \
# geoid                                                    1005
# name                                  Barbour County, Alabama
# universe                                                25782
# white_alone                                             11898
# black_alone                                             12199
# american_indian_and_alaska_native                          63
# asian_alone                                                85
# native_hawaiian_and_pacific_islander                        1
# other_alone                                                86
# two_or_more_races                                         344
# latino_alone                                             1106
# state                                                       1
# county                                                      5
# asians_all                                                 86
# other_all                                                 493
#
#                                                          3  \
# geoid                                                 1007
# name                                  Bibb County, Alabama
# universe                                             22527
# white_alone                                          16801
# black_alone                                           4974
# american_indian_and_alaska_native                        8
# asian_alone                                             37
# native_hawaiian_and_pacific_islander                     0
# other_alone                                              0
# two_or_more_races                                      160
# latino_alone                                           547
# state                                                    1
# county                                                   7
# asians_all                                              37
# other_all                                              168
#
#                                                            4
# geoid                                                   1009
# name                                  Blount County, Alabama
# universe                                               57645
# white_alone                                            50232
# black_alone                                              820
# american_indian_and_alaska_native                        124
# asian_alone                                              198
# native_hawaiian_and_pacific_islander                      18
# other_alone                                              174
# two_or_more_races                                        818
# latino_alone                                            5261
# state                                                      1
# county                                                     9
# asians_all                                               216
# other_all                                               1116

# %%
working_data.to_csv(PROCESSED_DATA / 'counties.csv', encoding = 'utf-8', index = False)
