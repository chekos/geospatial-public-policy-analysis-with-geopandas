# %% [markdown]
# # Are there any counties that don't have any higher education institutions (_education deserts_)?
#
# ## What are the (demographic) characteristics of those counties?

# %%
import pandas as pd
import geopandas as gpd
import geoplot as gplt
import geoplot.crs as gcrs
import matplotlib.pyplot as plt
from pathlib import Path

from tools import tree
from datetime import datetime as dt
today = dt.today().strftime("%d-%b-%y")

today
# Out:
# '23-Apr-20'

# %%
RAW_DATA = Path("../data/raw/")
INTERIM_DATA = Path("../data/interim/")
PROCESSED_DATA = Path("../data/processed/")
FINAL_DATA = Path("../data/final/")
EXTERNAL_DATA = Path("../data/external/")

# %%
tree(PROCESSED_DATA)
# Out:
# + ../data/processed
#     + counties.csv
#     + geodata
#         + tl_2019_us_county.cpg
#         + tl_2019_us_county.dbf
#         + tl_2019_us_county.prj
#         + tl_2019_us_county.shp
#         + tl_2019_us_county.shp.ea.iso.xml
#         + tl_2019_us_county.shp.iso.xml
#         + tl_2019_us_county.shx
#     + institutional_characteristics.csv
#     + processed_data.csv

# %%
county_data = pd.read_csv(PROCESSED_DATA / 'counties.csv')

# %%
county_data.head().T
# Out:
#                                                             0  \
# geoid                                                    1001
# name                                  Autauga County, Alabama
# universe                                                55200
# white_alone                                             41412
# black_alone                                             10475
# american_indian_and_alaska_native                         159
# asian_alone                                               568
# native_hawaiian_and_pacific_islander                        5
# other_alone                                                41
# two_or_more_races                                        1012
# latino_alone                                             1528
# state                                                       1
# county                                                      1
# asians_all                                                573
# other_all                                                1212
#
#                                                             1  \
# geoid                                                    1003
# name                                  Baldwin County, Alabama
# universe                                               208107
# white_alone                                            172768
# black_alone                                             19529
# american_indian_and_alaska_native                        1398
# asian_alone                                              1668
# native_hawaiian_and_pacific_islander                        9
# other_alone                                               410
# two_or_more_races                                        2972
# latino_alone                                             9353
# state                                                       1
# county                                                      3
# asians_all                                               1677
# other_all                                                4780
#
#                                                             2  \
# geoid                                                    1005
# name                                  Barbour County, Alabama
# universe                                                25782
# white_alone                                             11898
# black_alone                                             12199
# american_indian_and_alaska_native                          63
# asian_alone                                                85
# native_hawaiian_and_pacific_islander                        1
# other_alone                                                86
# two_or_more_races                                         344
# latino_alone                                             1106
# state                                                       1
# county                                                      5
# asians_all                                                 86
# other_all                                                 493
#
#                                                          3  \
# geoid                                                 1007
# name                                  Bibb County, Alabama
# universe                                             22527
# white_alone                                          16801
# black_alone                                           4974
# american_indian_and_alaska_native                        8
# asian_alone                                             37
# native_hawaiian_and_pacific_islander                     0
# other_alone                                              0
# two_or_more_races                                      160
# latino_alone                                           547
# state                                                    1
# county                                                   7
# asians_all                                              37
# other_all                                              168
#
#                                                            4
# geoid                                                   1009
# name                                  Blount County, Alabama
# universe                                               57645
# white_alone                                            50232
# black_alone                                              820
# american_indian_and_alaska_native                        124
# asian_alone                                              198
# native_hawaiian_and_pacific_islander                      18
# other_alone                                              174
# two_or_more_races                                        818
# latino_alone                                            5261
# state                                                      1
# county                                                     9
# asians_all                                               216
# other_all                                               1116

# %%
institutions_data = pd.read_csv(PROCESSED_DATA / 'institutional_characteristics.csv')

# %%
institutions_data.head().T
# Out:
#                                            0                             1  \
# institution_name      Aaniiih Nakoda College  Abilene Christian University
# longitude                           -108.758                      -99.7098
# latitude                             48.4842                       32.4689
# fips_state_code                      Montana                         Texas
# total_enrollment                         150                          5204
# full-time_enrollment                     108                          3730
# part-time_enrollment                      42                          1474
# control                               Public        Private not-for-profit
# level                                 2-year               4-year or above
#
#                                                          2  \
# institution_name      Abraham Baldwin Agricultural College
# longitude                                         -83.5283
# latitude                                           31.4819
# fips_state_code                                    Georgia
# total_enrollment                                      4291
# full-time_enrollment                                  2660
# part-time_enrollment                                  1631
# control                                             Public
# level                                      4-year or above
#
#                                                3                   4
# institution_name      Abraham Lincoln University     Academy College
# longitude                               -118.257            -93.2998
# latitude                                 34.1463             44.8557
# fips_state_code                       California           Minnesota
# total_enrollment                             217                  99
# full-time_enrollment                         194                  81
# part-time_enrollment                          23                  18
# control                       Private for-profit  Private for-profit
# level                            4-year or above     4-year or above

# %%
county_shapes = gpd.read_file(PROCESSED_DATA / 'geodata' / 'tl_2019_us_county.shp')

# %%
county_shapes.head().T
# Out:
#                                                           0  \
# STATEFP                                                  31
# COUNTYFP                                                039
# COUNTYNS                                           00835841
# GEOID                                                 31039
# NAME                                                 Cuming
# NAMELSAD                                      Cuming County
# LSAD                                                     06
# CLASSFP                                                  H1
# MTFCC                                                 G4020
# CSAFP                                                  None
# CBSAFP                                                 None
# METDIVFP                                               None
# FUNCSTAT                                                  A
# ALAND                                            1477652222
# AWATER                                             10690952
# INTPTLAT                                        +41.9158651
# INTPTLON                                       -096.7885168
# geometry  POLYGON ((-97.019516 42.004097, -97.019519 42....
#
#                                                           1  \
# STATEFP                                                  53
# COUNTYFP                                                069
# COUNTYNS                                           01513275
# GEOID                                                 53069
# NAME                                              Wahkiakum
# NAMELSAD                                   Wahkiakum County
# LSAD                                                     06
# CLASSFP                                                  H1
# MTFCC                                                 G4020
# CSAFP                                                  None
# CBSAFP                                                 None
# METDIVFP                                               None
# FUNCSTAT                                                  A
# ALAND                                             680962890
# AWATER                                             61582307
# INTPTLAT                                        +46.2946377
# INTPTLON                                       -123.4244583
# geometry  POLYGON ((-123.436394 46.238197, -123.447592 4...
#
#                                                           2  \
# STATEFP                                                  35
# COUNTYFP                                                011
# COUNTYNS                                           00933054
# GEOID                                                 35011
# NAME                                                De Baca
# NAMELSAD                                     De Baca County
# LSAD                                                     06
# CLASSFP                                                  H1
# MTFCC                                                 G4020
# CSAFP                                                  None
# CBSAFP                                                 None
# METDIVFP                                               None
# FUNCSTAT                                                  A
# ALAND                                            6016819475
# AWATER                                             29089486
# INTPTLAT                                        +34.3592729
# INTPTLON                                       -104.3686961
# geometry  POLYGON ((-104.567387 33.997566, -104.567717 3...
#
#                                                           3  \
# STATEFP                                                  31
# COUNTYFP                                                109
# COUNTYNS                                           00835876
# GEOID                                                 31109
# NAME                                              Lancaster
# NAMELSAD                                   Lancaster County
# LSAD                                                     06
# CLASSFP                                                  H1
# MTFCC                                                 G4020
# CSAFP                                                   339
# CBSAFP                                                30700
# METDIVFP                                               None
# FUNCSTAT                                                  A
# ALAND                                            2169270569
# AWATER                                             22849484
# INTPTLAT                                        +40.7835474
# INTPTLON                                       -096.6886584
# geometry  POLYGON ((-96.91075099999999 40.784944, -96.91...
#
#                                                           4
# STATEFP                                                  31
# COUNTYFP                                                129
# COUNTYNS                                           00835886
# GEOID                                                 31129
# NAME                                               Nuckolls
# NAMELSAD                                    Nuckolls County
# LSAD                                                     06
# CLASSFP                                                  H1
# MTFCC                                                 G4020
# CSAFP                                                  None
# CBSAFP                                                 None
# METDIVFP                                               None
# FUNCSTAT                                                  A
# ALAND                                            1489645188
# AWATER                                              1718484
# INTPTLAT                                        +40.1764918
# INTPTLON                                       -098.0468422
# geometry  POLYGON ((-98.27366699999999 40.089399, -98.27...

# %%
import us

# %%
contiguous_fips = [state.fips for state in us.STATES_CONTIGUOUS]
mask_contiguous_fips = county_shapes['STATEFP'].isin(contiguous_fips)
county_shapes = county_shapes[mask_contiguous_fips]

# %%
contiguous_states = [state.name for state in us.STATES_CONTIGUOUS]
mask_contiguous_states = institutions_data['fips_state_code'].isin(contiguous_states)
institutions_data = institutions_data[mask_contiguous_states]

# %% [markdown]
# ### Majority underrepresented group??

# %%
county_data.head().T
# Out:
#                                                             0  \
# geoid                                                    1001
# name                                  Autauga County, Alabama
# universe                                                55200
# white_alone                                             41412
# black_alone                                             10475
# american_indian_and_alaska_native                         159
# asian_alone                                               568
# native_hawaiian_and_pacific_islander                        5
# other_alone                                                41
# two_or_more_races                                        1012
# latino_alone                                             1528
# state                                                       1
# county                                                      1
# asians_all                                                573
# other_all                                                1212
#
#                                                             1  \
# geoid                                                    1003
# name                                  Baldwin County, Alabama
# universe                                               208107
# white_alone                                            172768
# black_alone                                             19529
# american_indian_and_alaska_native                        1398
# asian_alone                                              1668
# native_hawaiian_and_pacific_islander                        9
# other_alone                                               410
# two_or_more_races                                        2972
# latino_alone                                             9353
# state                                                       1
# county                                                      3
# asians_all                                               1677
# other_all                                                4780
#
#                                                             2  \
# geoid                                                    1005
# name                                  Barbour County, Alabama
# universe                                                25782
# white_alone                                             11898
# black_alone                                             12199
# american_indian_and_alaska_native                          63
# asian_alone                                                85
# native_hawaiian_and_pacific_islander                        1
# other_alone                                                86
# two_or_more_races                                         344
# latino_alone                                             1106
# state                                                       1
# county                                                      5
# asians_all                                                 86
# other_all                                                 493
#
#                                                          3  \
# geoid                                                 1007
# name                                  Bibb County, Alabama
# universe                                             22527
# white_alone                                          16801
# black_alone                                           4974
# american_indian_and_alaska_native                        8
# asian_alone                                             37
# native_hawaiian_and_pacific_islander                     0
# other_alone                                              0
# two_or_more_races                                      160
# latino_alone                                           547
# state                                                    1
# county                                                   7
# asians_all                                              37
# other_all                                              168
#
#                                                            4
# geoid                                                   1009
# name                                  Blount County, Alabama
# universe                                               57645
# white_alone                                            50232
# black_alone                                              820
# american_indian_and_alaska_native                        124
# asian_alone                                              198
# native_hawaiian_and_pacific_islander                      18
# other_alone                                              174
# two_or_more_races                                        818
# latino_alone                                            5261
# state                                                      1
# county                                                     9
# asians_all                                               216
# other_all                                               1116

# %%
county_data['share_underrepresented'] = (county_data['black_alone'] + 
    county_data['american_indian_and_alaska_native'] + 
    county_data['native_hawaiian_and_pacific_islander'] + 
    county_data['latino_alone']) / county_data['universe']

# %%
county_data.head().T
# Out:
#                                                             0  \
# geoid                                                    1001
# name                                  Autauga County, Alabama
# universe                                                55200
# white_alone                                             41412
# black_alone                                             10475
# american_indian_and_alaska_native                         159
# asian_alone                                               568
# native_hawaiian_and_pacific_islander                        5
# other_alone                                                41
# two_or_more_races                                        1012
# latino_alone                                             1528
# state                                                       1
# county                                                      1
# asians_all                                                573
# other_all                                                1212
# share_underrepresented                               0.220417
#
#                                                             1  \
# geoid                                                    1003
# name                                  Baldwin County, Alabama
# universe                                               208107
# white_alone                                            172768
# black_alone                                             19529
# american_indian_and_alaska_native                        1398
# asian_alone                                              1668
# native_hawaiian_and_pacific_islander                        9
# other_alone                                               410
# two_or_more_races                                        2972
# latino_alone                                             9353
# state                                                       1
# county                                                      3
# asians_all                                               1677
# other_all                                                4780
# share_underrepresented                               0.145545
#
#                                                             2  \
# geoid                                                    1005
# name                                  Barbour County, Alabama
# universe                                                25782
# white_alone                                             11898
# black_alone                                             12199
# american_indian_and_alaska_native                          63
# asian_alone                                                85
# native_hawaiian_and_pacific_islander                        1
# other_alone                                                86
# two_or_more_races                                         344
# latino_alone                                             1106
# state                                                       1
# county                                                      5
# asians_all                                                 86
# other_all                                                 493
# share_underrepresented                                0.51854
#
#                                                          3  \
# geoid                                                 1007
# name                                  Bibb County, Alabama
# universe                                             22527
# white_alone                                          16801
# black_alone                                           4974
# american_indian_and_alaska_native                        8
# asian_alone                                             37
# native_hawaiian_and_pacific_islander                     0
# other_alone                                              0
# two_or_more_races                                      160
# latino_alone                                           547
# state                                                    1
# county                                                   7
# asians_all                                              37
# other_all                                              168
# share_underrepresented                            0.245439
#
#                                                            4
# geoid                                                   1009
# name                                  Blount County, Alabama
# universe                                               57645
# white_alone                                            50232
# black_alone                                              820
# american_indian_and_alaska_native                        124
# asian_alone                                              198
# native_hawaiian_and_pacific_islander                      18
# other_alone                                              174
# two_or_more_races                                        818
# latino_alone                                            5261
# state                                                      1
# county                                                     9
# asians_all                                               216
# other_all                                               1116
# share_underrepresented                              0.107954

# %%
subset_county_data = county_data[['geoid', 'name', 'share_underrepresented']].copy()
subset_county_shapes = county_shapes[['GEOID', 'NAME', 'geometry']].copy()

# %%
subset_county_data['geoid'] = subset_county_data['geoid'].astype(str).str.zfill(5)

# %%
subset_county_data.set_index('geoid', inplace = True)
subset_county_shapes.set_index('GEOID', inplace = True)

# %%
working_gdf = subset_county_shapes.join(subset_county_data)

# %%
working_gdf.crs
# Out:
# <Geographic 2D CRS: EPSG:4269>
# Name: NAD83
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: North America - NAD83
# - bounds: (167.65, 14.92, -47.74, 86.46)
# Datum: North American Datum 1983
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %%
geo_institutions = gpd.GeoDataFrame(institutions_data, geometry = gpd.points_from_xy(institutions_data['longitude'], institutions_data['latitude']))

# %%
geo_institutions.crs = working_gdf.crs

# %%
counties_with_institutions = gpd.sjoin(working_gdf, geo_institutions, how='inner', op='contains')

# %%
counties_with_institutions = counties_with_institutions.drop_duplicates('name')

# %%
working_gdf.shape
# Out:
# (3108, 4)

# %%
counties_with_institutions.shape
# Out:
# (1272, 14)

# %%
counties_with_institutions.plot();

# %%
counties_without_institutions_list = [county for county in working_gdf['name'].values if county not in counties_with_institutions['name'].values]
mask_counties_without_institutions = working_gdf['name'].isin(counties_without_institutions_list)

# %%
counties_without_institutions = working_gdf[mask_counties_without_institutions]

counties_without_institutions.plot();

# %% [markdown]
# # Characteristics of each subset

# %%
gplt.choropleth(counties_with_institutions, projection=gcrs.WebMercator(), hue = 'share_underrepresented', figsize=(12,12))

# %%
gplt.choropleth(counties_without_institutions, projection=gcrs.WebMercator(), hue = 'share_underrepresented', figsize=(12,12))

# %%
counties_with_institutions.head().T
# Out:
# GEOID                                                               31109  \
# NAME                                                            Lancaster
# geometry                POLYGON ((-96.91075099999999 40.784944, -96.91...
# name                                           Lancaster County, Nebraska
# share_underrepresented                                           0.112537
# index_right                                                          1996
# institution_name                                     Myotherapy Institute
# longitude                                                        -96.6233
# latitude                                                          40.7723
# fips_state_code                                                  Nebraska
# total_enrollment                                                       11
# full-time_enrollment                                                   11
# part-time_enrollment                                                    0
# control                                                Private for-profit
# level                                                              2-year
#
# GEOID                                                               46099  \
# NAME                                                            Minnehaha
# geometry                POLYGON ((-97.129283 43.58682599999999, -97.12...
# name                                       Minnehaha County, South Dakota
# share_underrepresented                                           0.124772
# index_right                                                           173
# institution_name                                     Augustana University
# longitude                                                         -96.737
# latitude                                                          43.5251
# fips_state_code                                              South Dakota
# total_enrollment                                                     2133
# full-time_enrollment                                                 1754
# part-time_enrollment                                                  379
# control                                            Private not-for-profit
# level                                                     4-year or above
#
# GEOID                                                               39063  \
# NAME                                                              Hancock
# geometry                POLYGON ((-83.88076199999999 41.080361, -83.88...
# name                                                 Hancock County, Ohio
# share_underrepresented                                          0.0674858
# index_right                                                          3097
# institution_name                                The University of Findlay
# longitude                                                        -83.6523
# latitude                                                          41.0533
# fips_state_code                                                      Ohio
# total_enrollment                                                     4870
# full-time_enrollment                                                 3092
# part-time_enrollment                                                 1778
# control                                            Private not-for-profit
# level                                                     4-year or above
#
# GEOID                                                               48189  \
# NAME                                                                 Hale
# geometry                POLYGON ((-102.087626 34.026563, -102.087792 3...
# name                                                   Hale County, Texas
# share_underrepresented                                           0.634831
# index_right                                                          3560
# institution_name                               Wayland Baptist University
# longitude                                                         -101.73
# latitude                                                          34.1877
# fips_state_code                                                     Texas
# total_enrollment                                                     4504
# full-time_enrollment                                                 1014
# part-time_enrollment                                                 3490
# control                                            Private not-for-profit
# level                                                     4-year or above
#
# GEOID                                                               39003
# NAME                                                                Allen
# geometry                POLYGON ((-84.397189 40.786584, -84.397198 40....
# name                                                   Allen County, Ohio
# share_underrepresented                                           0.149582
# index_right                                                          1481
# institution_name                             James A Rhodes State College
# longitude                                                        -84.0263
# latitude                                                          40.7383
# fips_state_code                                                      Ohio
# total_enrollment                                                     4002
# full-time_enrollment                                                  764
# part-time_enrollment                                                 3238
# control                                                            Public
# level                                                              2-year

# %%
counties_with_institutions['share_underrepresented'].mean()
# Out:
# 0.22446120819235205

# %%
counties_without_institutions['share_underrepresented'].mean()
# Out:
# 0.18169141152568655

# %%
counties_without_institutions.head()
# Out:
#             NAME                                           geometry  \
# GEOID
# 31039     Cuming  POLYGON ((-97.01952 42.00410, -97.01952 42.004...
# 53069  Wahkiakum  POLYGON ((-123.43639 46.23820, -123.44759 46.2...
# 35011    De Baca  POLYGON ((-104.56739 33.99757, -104.56772 33.9...
# 31129   Nuckolls  POLYGON ((-98.27367 40.08940, -98.27367 40.089...
# 48327     Menard  POLYGON ((-99.82187 31.08721, -99.81877 31.087...
#
#                                name  share_underrepresented
# GEOID
# 31039       Cuming County, Nebraska                0.102769
# 53069  Wahkiakum County, Washington                0.088327
# 35011    De Baca County, New Mexico                0.476699
# 31129     Nuckolls County, Nebraska                0.029474
# 48327          Menard County, Texas                0.355158

# %% [markdown]
# Now that we have the list of counties with and without institutions we can use `census-data-downloader` to explore more statistics about these counties.
#
#
# on your terminal, let's get mendianhouseholdincome and medianage

# %% [markdown]
# ***
# After you run it...

# %%
tree(EXTERNAL_DATA)
# Out:
# + ../data/external
#     + 4-8-2020---748.zip
#     + processed
#             + acs5_2018_race_counties-checkpoint.csv
#         + acs5_2018_medianage_counties.csv
#         + acs5_2018_medianhouseholdincome_counties.csv
#         + acs5_2018_race_counties.csv
#     + raw
#         + acs5_2018_medianage_counties.csv
#         + acs5_2018_medianhouseholdincome_counties.csv
#         + acs5_2018_race_counties.csv
#     + tl_2019_us_county.zip

# %%
median_age = pd.read_csv(EXTERNAL_DATA / 'processed' / 'acs5_2018_medianage_counties.csv')
median_hh_income = pd.read_csv(EXTERNAL_DATA / 'processed' / 'acs5_2018_medianhouseholdincome_counties.csv')

# %%
median_age.head()
# Out:
#    geoid                           name  median  median_annotation  \
# 0  30019        Daniels County, Montana    50.7                NaN
# 1  72073  Jayuya Municipio, Puerto Rico    37.8                NaN
# 2  39173              Wood County, Ohio    34.8                NaN
# 3  24023       Garrett County, Maryland    45.6                NaN
# 4  30079        Prairie County, Montana    51.8                NaN
#
#    median_moe  median_moe_annotation  male  male_annotation  male_moe  \
# 0         4.9                    NaN  49.4              NaN       7.5
# 1         0.9                    NaN  36.1              NaN       1.1
# 2         0.2                    NaN  33.6              NaN       0.3
# 3         0.3                    NaN  44.4              NaN       0.4
# 4         7.0                    NaN  53.0              NaN       7.5
#
#    male_moe_annotation  female  female_annotation  female_moe  \
# 0                  NaN    52.3                NaN         6.3
# 1                  NaN    40.1                NaN         2.5
# 2                  NaN    36.0                NaN         0.3
# 3                  NaN    47.0                NaN         0.5
# 4                  NaN    49.7                NaN         6.8
#
#    female_moe_annotation  state  county
# 0                    NaN     30      19
# 1                    NaN     72      73
# 2                    NaN     39     173
# 3                    NaN     24      23
# 4                    NaN     30      79

# %%
median_hh_income.head()
# Out:
#    geoid                           name   median  median_annotation  \
# 0  30019        Daniels County, Montana  54750.0                NaN
# 1  72073  Jayuya Municipio, Puerto Rico  15424.0                NaN
# 2  39173              Wood County, Ohio  59789.0                NaN
# 3  24023       Garrett County, Maryland  49619.0                NaN
# 4  30079        Prairie County, Montana  47250.0                NaN
#
#    median_moe  median_moe_annotation  state  county
# 0      2497.0                    NaN     30      19
# 1      2978.0                    NaN     72      73
# 2      1513.0                    NaN     39     173
# 3      1948.0                    NaN     24      23
# 4      6386.0                    NaN     30      79

# %%
# fix geoid
median_age['geoid'] = median_age['geoid'].astype(str).str.zfill(5)
median_hh_income['geoid'] = median_hh_income['geoid'].astype(str).str.zfill(5)

# %%
median_age = median_age[['geoid', 'median', 'male', 'female']]
median_age.columns = ['geoid', 'median_age', 'median_age_male', 'median_age_female']
median_age.set_index('geoid', inplace = True)

# %%
median_hh_income = median_hh_income[['geoid', 'median']]
median_hh_income.columns = ['geoid', 'median_hh_income']
median_hh_income.set_index('geoid', inplace=True)

# %%
counties_with_institutions = counties_with_institutions.join(median_age, how = 'left',).join(median_hh_income, how = 'left')

# %%
counties_without_institutions = counties_without_institutions.join(median_age, how = 'left',).join(median_hh_income, how = 'left')

# %% [markdown]
# More stats

# %%
columns_of_interest = [
    'median_age', 
    'median_age_male', 
    'median_age_female', 
    'median_hh_income', 
    'share_underrepresented',
]

# %%
counties_with_institutions[columns_of_interest].describe()
# Out:
#         median_age  median_age_male  median_age_female  median_hh_income  \
# count  1272.000000      1272.000000        1272.000000       1271.000000
# mean     39.022956        37.690959          40.380503      54352.334382
# std       4.853074         4.708997           5.044979      14574.964608
# min      21.700000        21.200000          22.600000      21093.000000
# 25%      36.100000        34.900000          37.300000      44808.500000
# 50%      39.300000        37.800000          40.700000      51829.000000
# 75%      41.900000        40.500000          43.600000      60377.500000
# max      57.900000        56.600000          58.600000     121133.000000
#
#        share_underrepresented
# count             1272.000000
# mean                 0.224461
# std                  0.191612
# min                  0.015697
# 25%                  0.074730
# 50%                  0.155409
# 75%                  0.327119
# max                  0.958372

# %%
counties_without_institutions[columns_of_interest].describe()
# Out:
#         median_age  median_age_male  median_age_female  median_hh_income  \
# count  1836.000000      1836.000000        1836.000000       1836.000000
# mean     42.918083        41.599510          44.302723      49354.568627
# std       5.155767         5.338054           5.155822      12479.289766
# min      23.700000        21.600000          26.400000      20188.000000
# 25%      39.800000        38.300000          41.300000      40899.750000
# 50%      42.700000        41.200000          44.200000      48373.500000
# 75%      46.000000        44.600000          47.300000      55473.750000
# max      67.000000        66.500000          67.300000     136268.000000
#
#        share_underrepresented
# count             1836.000000
# mean                 0.181691
# std                  0.192897
# min                  0.000000
# 25%                  0.038773
# 50%                  0.096512
# 75%                  0.281957
# max                  0.991126
